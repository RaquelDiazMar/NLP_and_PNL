# %% [markdown]
# ### What it word2vec?
#
# It is a shallow, two-layer neural network that accepts a text corpus as an input, and it returns a set of vectors (also known as embeddings); each vector is a numeric representation of a given word.
#
# "You shall know a word by the company it keeps." Meaning: you can infer the meaning of a word by just looking at the words around it in the context of a sentence.
#
# The skip-gram method: uses the words around each word to understand the context and create a numeric representation of that word. This is how it learns numeric vector representations of every word in the corpus it's trained on.
#
# A word2vec model is a two-layer neural network that will convert a list of words into a list of numeric vectors.
#
# To gauge word similarity you can use word vectors. The most common way to calculate this similarity is using cosine similarity. In Python, you just pass two word vectors into the cosine similarity function, and it will return a score between -1 and 1 as a similarity measure. What it's actually doing is returning the cosine of the angle between these two vectors. Now, recall what a cosine curve looks like. The X axis in the small plot would represent the angle between two vectors, and then the Y axis is the similarity score that would be returned. So if the angle between two vectors is very, very small, near zero, then the similarity score would be very close to one. If the angle between two vectors is 180 degrees, the similarity score is -1, or opposites.

# %%
# Install gensim
# !pip install -U gensim
# Out:
# Collecting gensim
#   Downloading gensim-3.8.3-cp37-cp37m-win_amd64.whl (24.2 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in c:\users\34677\anaconda3\lib\site-packages (from gensim) (1.19.0)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-2.1.1.tar.gz (111 kB)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in c:\users\34677\anaconda3\lib\site-packages (from gensim) (1.15.0)
# Collecting Cython==0.29.14
#   Downloading Cython-0.29.14-cp37-cp37m-win_amd64.whl (1.7 MB)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\users\34677\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: requests in c:\users\34677\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.24.0)
# Requirement already satisfied, skipping upgrade: boto in c:\users\34677\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Collecting boto3
#   Downloading boto3-1.14.51-py2.py3-none-any.whl (129 kB)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\34677\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\34677\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\34677\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.9)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\34677\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.10)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.18.0,>=1.17.51
#   Downloading botocore-1.17.51-py2.py3-none-any.whl (6.6 MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in c:\users\34677\anaconda3\lib\site-packages (from botocore<1.18.0,>=1.17.51->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Building wheels for collected packages: smart-open
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-2.1.1-py3-none-any.whl size=112418 sha256=4c332f39078b18c7e7dc48d15b46d8fbed93c7066f867dcd9922effc410d4e6f
#   Stored in directory: c:\users\34677\appdata\local\pip\cache\wheels\d5\75\1d\d3da0d094f5e2ea61bddb9cb8cd4bd3ab9fb648e7269620855
# Successfully built smart-open
# Installing collected packages: jmespath, docutils, botocore, s3transfer, boto3, smart-open, Cython, gensim
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.15
#     Uninstalling Cython-0.29.15:
#       Successfully uninstalled Cython-0.29.15
# Successfully installed Cython-0.29.14 boto3-1.14.51 botocore-1.17.51 docutils-0.15.2 gensim-3.8.3 jmespath-0.10.0 s3transfer-0.3.3 smart-open-2.1.1
# WARNING: You are using pip version 20.1.1; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\34677\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Load pretrained word vectors using gensim
import gensim.downloader as api

wiki_embeddings = api.load('glove-wiki-gigaword-100')
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
# Explore the word vector for "king"
wiki_embeddings['king']
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
#        -0.91627 ,  0.64521 ,  0.73281 , -0.22752 ,  0.30226 ,  0.044801,
#        -0.83741 ,  0.55006 , -0.52506 , -1.7357  ,  0.4751  , -0.70487 ,
#         0.056939, -0.7132  ,  0.089623,  0.41394 , -1.3363  , -0.61915 ,
#        -0.33089 , -0.52881 ,  0.16483 , -0.98878 ], dtype=float32)

# %%
# Find the words most similar to king based on the trained word vectors
wiki_embeddings.most_similar('king')
# Out:
# [('prince', 0.7682329416275024),
#  ('queen', 0.7507690191268921),
#  ('son', 0.7020887136459351),
#  ('brother', 0.6985775232315063),
#  ('monarch', 0.6977890729904175),
#  ('throne', 0.6919990181922913),
#  ('kingdom', 0.6811410188674927),
#  ('father', 0.6802029013633728),
#  ('emperor', 0.6712857484817505),
#  ('ii', 0.6676074266433716)]

# %%
wiki_embeddings.most_similar('love')
# Out:
# [('me', 0.7382813692092896),
#  ('passion', 0.735213577747345),
#  ('my', 0.7327208518981934),
#  ('life', 0.7287957668304443),
#  ('dream', 0.7267670035362244),
#  ('you', 0.7181724309921265),
#  ('always', 0.7111519575119019),
#  ('wonder', 0.7094581127166748),
#  ('i', 0.7084634304046631),
#  ('dreams', 0.7067317962646484)]

# %%
# Train the model
# Read in the data and clean up column names
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though

# %%
# Clean data using the built in cleaner in gensim
messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
messages.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
#
#                                                                                             text_clean
# 0  [go, until, jurong, point, crazy, available, only, in, bugis, great, world, la, buffet, cine, th...
# 1                                                                          [ok, lar, joking, wif, oni]
# 2  [free, entry, in, wkly, comp, to, win, fa, cup, final, tkts, st, may, text, fa, to, to, receive,...
# 3                                                       [dun, say, so, early, hor, already, then, say]
# 4                                [nah, don, think, he, goes, to, usf, he, lives, around, here, though]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

# %%
# Train the word2vec model
w2v_model = gensim.models.Word2Vec(X_train,
                                   size=100,
                                   window=5,
                                   min_count=2)

# %%
# Explore the word vector for "king" base on trained model
w2v_model.wv['king']
# Out:
# array([ 0.04663172,  0.03127421,  0.06469775, -0.00727583,  0.04726887,
#        -0.00250307, -0.0503101 ,  0.01107288,  0.01183673, -0.03182893,
#         0.00755053, -0.05057079,  0.002737  ,  0.01299583, -0.01232938,
#         0.06443909,  0.05830617, -0.01431434, -0.05226093, -0.04732038,
#        -0.03040092,  0.02699241,  0.01060657,  0.05214865, -0.00116046,
#         0.00930923,  0.02095554, -0.04127254, -0.02117939, -0.00923504,
#         0.01227929, -0.02265489, -0.02632529,  0.01250261,  0.00870887,
#         0.02763297, -0.00019156,  0.00449696,  0.01953203,  0.03260936,
#        -0.00262226,  0.02667082,  0.02193566, -0.04284675, -0.01995637,
#        -0.01998122,  0.03369087, -0.08635699, -0.01910882, -0.03533529,
#        -0.00825467,  0.02114196,  0.07797874, -0.02580586,  0.07644919,
#         0.0197979 , -0.01137579,  0.00389541, -0.0131095 , -0.03545333,
#        -0.0125977 ,  0.0209763 ,  0.01070945, -0.04768215,  0.030259  ,
#         0.02032248, -0.05188434, -0.02868261, -0.02285695,  0.08286031,
#        -0.03257317,  0.026163  ,  0.00656968,  0.0320964 ,  0.00779694,
#        -0.01410015, -0.03903747, -0.0240854 , -0.06330752, -0.04812984,
#        -0.03168631, -0.02201608,  0.02118091, -0.04425136,  0.01314122,
#        -0.06369668,  0.00774988, -0.00660307, -0.03609148, -0.02013428,
#        -0.00588545, -0.03475537, -0.06241657, -0.02358521,  0.03506538,
#        -0.01399898, -0.04688087, -0.00582909, -0.02662149, -0.1090998 ],
#       dtype=float32)

# %%
# Find the most similar words to "king" based on word vectors from trained model
w2v_model.wv.most_similar('king')
# Out:
# [('has', 0.9973573088645935),
#  ('contact', 0.9973569512367249),
#  ('use', 0.9973336458206177),
#  ('yr', 0.9973284006118774),
#  ('hl', 0.9973279237747192),
#  ('before', 0.997320294380188),
#  ('good', 0.9973108768463135),
#  ('girl', 0.9973031878471375),
#  ('until', 0.9972975254058838),
#  ('st', 0.9972960352897644)]

# %%
# Generate a list of words the word2vec model learned word vectors for
w2v_model.wv.index2word
# Out:
# ['you',
#  'to',
#  'the',
#  'and',
#  'is',
#  'in',
#  'me',
#  'my',
#  'it',
#  'for',
#  'your',
#  'of',
#  'call',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'not',
#  'so',
#  'but',
#  'we',
#  'or',
#  'at',
#  'do',
#  'if',
#  'ur',
#  'get',
#  'with',
#  'will',
#  'no',
#  'be',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'up',
#  'how',
#  'go',
#  'ok',
#  'when',
#  'what',
#  'from',
#  'free',
#  'll',
#  'all',
#  'out',
#  'know',
#  'then',
#  'am',
#  'good',
#  'there',
#  'like',
#  'he',
#  'day',
#  'time',
#  'got',
#  'was',
#  'come',
#  'only',
#  'its',
#  'love',
#  'text',
#  'send',
#  'txt',
#  'want',
#  'by',
#  'as',
#  'about',
#  'going',
#  'lor',
#  'need',
#  'one',
#  'she',
#  'sorry',
#  'stop',
#  'home',
#  'back',
#  'still',
#  'see',
#  'don',
#  'today',
#  'da',
#  'our',
#  'reply',
#  'tell',
#  'new',
#  'later',
#  'think',
#  'hi',
#  'please',
#  'did',
#  'week',
#  'mobile',
#  'any',
#  'take',
#  'pls',
#  'they',
#  'dear',
#  'been',
#  'dont',
#  'some',
#  'who',
#  'her',
#  're',
#  'phone',
#  'ì_',
#  'much',
#  'where',
#  'hey',
#  'claim',
#  'oh',
#  'night',
#  'here',
#  'give',
#  'has',
#  'msg',
#  'great',
#  'happy',
#  'wat',
#  'him',
#  'well',
#  'hope',
#  'had',
#  'an',
#  'more',
#  'yes',
#  'too',
#  'work',
#  'way',
#  'right',
#  'already',
#  'number',
#  'www',
#  've',
#  'cash',
#  'message',
#  'ask',
#  'prize',
#  'doing',
#  'should',
#  'make',
#  'yeah',
#  'won',
#  'tomorrow',
#  'after',
#  'babe',
#  'really',
#  'say',
#  'win',
#  'why',
#  'im',
#  'amp',
#  'them',
#  'meet',
#  'very',
#  'nokia',
#  'last',
#  'said',
#  'cos',
#  'find',
#  'min',
#  'also',
#  'lol',
#  'let',
#  'morning',
#  'wait',
#  'life',
#  'miss',
#  'uk',
#  'anything',
#  'pick',
#  'before',
#  'care',
#  'thanks',
#  'first',
#  'com',
#  'every',
#  'again',
#  'someone',
#  'buy',
#  'over',
#  'contact',
#  'sent',
#  'would',
#  'sure',
#  'cant',
#  'something',
#  'tone',
#  'next',
#  'help',
#  'late',
#  'tonight',
#  'down',
#  'which',
#  'soon',
#  'were',
#  'urgent',
#  'thing',
#  'us',
#  'even',
#  'ya',
#  'service',
#  'nice',
#  'wan',
#  'wish',
#  'keep',
#  'many',
#  'could',
#  'box',
#  'money',
#  'mins',
#  'dun',
#  'sms',
#  'his',
#  'st',
#  'sleep',
#  'off',
#  'gonna',
#  'name',
#  'place',
#  'customer',
#  'went',
#  'told',
#  'around',
#  'feel',
#  'leave',
#  'other',
#  'per',
#  'friends',
#  'thought',
#  'heart',
#  'use',
#  'friend',
#  'always',
#  'chat',
#  'gud',
#  'ìï',
#  'co',
#  'thk',
#  'pm',
#  'people',
#  'hello',
#  'things',
#  'year',
#  'done',
#  'waiting',
#  'try',
#  'days',
#  'may',
#  'yet',
#  'getting',
#  'same',
#  'guaranteed',
#  'special',
#  'meeting',
#  'haha',
#  'didn',
#  'bit',
#  'having',
#  'stuff',
#  'person',
#  'class',
#  'ppm',
#  'god',
#  'best',
#  'lunch',
#  'fine',
#  'enjoy',
#  'thats',
#  'world',
#  'dat',
#  'being',
#  'man',
#  'finish',
#  'car',
#  'account',
#  'half',
#  'th',
#  'ready',
#  'few',
#  'cool',
#  'mind',
#  'end',
#  'talk',
#  'big',
#  'guess',
#  'live',
#  'pobox',
#  'month',
#  'better',
#  'long',
#  'smile',
#  'lar',
#  'play',
#  'yup',
#  'nothing',
#  'liao',
#  'trying',
#  'chance',
#  'coming',
#  'problem',
#  'receive',
#  'ill',
#  'guys',
#  'real',
#  'shopping',
#  'jus',
#  'shit',
#  'wanna',
#  'cs',
#  'dinner',
#  'sir',
#  'house',
#  'might',
#  'yo',
#  'watching',
#  'awarded',
#  'bt',
#  'check',
#  'ah',
#  'latest',
#  'holiday',
#  'speak',
#  'eat',
#  'aight',
#  'two',
#  'line',
#  'shows',
#  'sweet',
#  'word',
#  'wk',
#  'job',
#  'cost',
#  'look',
#  'because',
#  'minutes',
#  'probably',
#  'weekend',
#  'draw',
#  'sat',
#  'rate',
#  'thanx',
#  'once',
#  'pa',
#  'camera',
#  'dunno',
#  'den',
#  'birthday',
#  'video',
#  'than',
#  'mail',
#  'calls',
#  'called',
#  'fun',
#  'tones',
#  'little',
#  'tv',
#  'landline',
#  'easy',
#  'bad',
#  'lot',
#  'code',
#  'into',
#  'evening',
#  'maybe',
#  'girl',
#  'room',
#  'shall',
#  'plan',
#  'bed',
#  'does',
#  'age',
#  'while',
#  'never',
#  'nite',
#  'po',
#  'nd',
#  'made',
#  'xxx',
#  'watch',
#  'hrs',
#  'apply',
#  'quite',
#  'enough',
#  'leh',
#  'start',
#  'between',
#  'princess',
#  'dad',
#  'remember',
#  'offer',
#  'early',
#  'put',
#  'wont',
#  'didnt',
#  'boy',
#  'luv',
#  'anyway',
#  'another',
#  'kiss',
#  'orange',
#  'actually',
#  'ringtone',
#  'office',
#  'award',
#  'selected',
#  'wife',
#  'forgot',
#  'juz',
#  'part',
#  'since',
#  'without',
#  'thank',
#  'pay',
#  'dis',
#  'reach',
#  'texts',
#  'asked',
#  'bring',
#  'left',
#  'times',
#  'baby',
#  'town',
#  'wake',
#  'says',
#  'everything',
#  'network',
#  'wif',
#  'means',
#  'those',
#  'fuck',
#  'club',
#  'gift',
#  'til',
#  'xx',
#  'join',
#  'else',
#  'collect',
#  'working',
#  'years',
#  'ever',
#  'missed',
#  'hear',
#  'messages',
#  'entry',
#  'details',
#  'must',
#  'true',
#  'makes',
#  'guy',
#  'price',
#  'tried',
#  'till',
#  'oso',
#  'important',
#  'bus',
#  'looking',
#  'wanted',
#  'alright',
#  'afternoon',
#  'wot',
#  'xmas',
#  'change',
#  'online',
#  'mob',
#  'goes',
#  'came',
#  'national',
#  'yesterday',
#  'run',
#  'saw',
#  'both',
#  'question',
#  'show',
#  'friendship',
#  'tmr',
#  'chikku',
#  'id',
#  'abt',
#  'pain',
#  'net',
#  'wen',
#  'most',
#  'gr',
#  'plz',
#  'game',
#  'goin',
#  'either',
#  'lose',
#  'sexy',
#  'until',
#  'movie',
#  'bored',
#  'feeling',
#  'valid',
#  'poly',
#  'answer',
#  'school',
#  'de',
#  'hot',
#  'charge',
#  'together',
#  'words',
#  'drive',
#  'optout',
#  'okay',
#  'away',
#  'worry',
#  'saying',
#  'food',
#  'lei',
#  'trip',
#  'decimal',
#  'driving',
#  'hurt',
#  'private',
#  'points',
#  'havent',
#  'nt',
#  'hour',
#  'able',
#  'top',
#  'simple',
#  'believe',
#  'plus',
#  'row',
#  'drink',
#  'unsubscribe',
#  'wants',
#  'hav',
#  'double',
#  'happen',
#  'set',
#  'noe',
#  'break',
#  'dude',
#  'old',
#  'stay',
#  'final',
#  'close',
#  'gd',
#  'hl',
#  'forget',
#  'shop',
#  'brother',
#  'missing',
#  'address',
#  'taking',
#  'book',
#  'walk',
#  'these',
#  'calling',
#  'awesome',
#  'tomo',
#  'thinking',
#  'head',
#  'tho',
#  'sis',
#  'company',
#  'weekly',
#  'sister',
#  'alone',
#  'yourself',
#  'delivery',
#  'minute',
#  'bonus',
#  'hours',
#  'test',
#  'okie',
#  'statement',
#  'expires',
#  'story',
#  'music',
#  'parents',
#  'http',
#  'smiling',
#  'eve',
#  'colour',
#  'smoke',
#  'collection',
#  'sch',
#  'attempt',
#  'college',
#  'huh',
#  'though',
#  'drop',
#  'pub',
#  'wid',
#  'making',
#  'yours',
#  'lets',
#  'mum',
#  'hair',
#  'tot',
#  'msgs',
#  'mths',
#  'full',
#  'identifier',
#  'family',
#  'games',
#  'haf',
#  'face',
#  'sad',
#  'date',
#  'haven',
#  'took',
#  'darlin',
#  'info',
#  'started',
#  'finished',
#  'hows',
#  'ha',
#  'open',
#  'busy',
#  'vouchers',
#  'aft',
#  'services',
#  'order',
#  'news',
#  'sun',
#  'mean',
#  'coz',
#  'treat',
#  'crazy',
#  'opt',
#  'voucher',
#  'wil',
#  'doesn',
#  'decided',
#  'takes',
#  'credit',
#  'suite',
#  'yr',
#  'update',
#  'choose',
#  'dating',
#  'auction',
#  'sleeping',
#  'email',
#  'read',
#  'sae',
#  'far',
#  'anytime',
#  'light',
#  'kind',
#  'seeing',
#  'hit',
#  'whatever',
#  'wq',
#  'beautiful',
#  'angry',
#  'await',
#  'snow',
#  'content',
#  'mine',
#  'boytoy',
#  'txts',
#  'available',
#  'mobileupd',
#  'hungry',
#  'smth',
#  'carlos',
#  'used',
#  'oredi',
#  'leaving',
#  'loving',
#  'cum',
#  'lots',
#  'second',
#  'side',
#  'hmm',
#  'lands',
#  'nope',
#  'fast',
#  'chennai',
#  'search',
#  'quiz',
#  'worth',
#  'found',
#  'gbp',
#  'tel',
#  'neva',
#  'sounds',
#  'cause',
#  'lesson',
#  'unlimited',
#  'camcorder',
#  'frm',
#  'ard',
#  'todays',
#  'prob',
#  'fri',
#  'player',
#  'fone',
#  'ring',
#  'card',
#  'dreams',
#  'winner',
#  'finally',
#  'type',
#  'knw',
#  'mates',
#  'gym',
#  'motorola',
#  'phones',
#  'semester',
#  'weeks',
#  'touch',
#  'rite',
#  'anyone',
#  'bout',
#  'frnd',
#  'ish',
#  'reading',
#  'yrs',
#  'party',
#  'girls',
#  'visit',
#  'hmmm',
#  'pounds',
#  'lovely',
#  'mom',
#  'pretty',
#  'welcome',
#  'gas',
#  'rs',
#  'wkly',
#  'thinks',
#  'their',
#  'savamob',
#  'pics',
#  'whats',
#  'hard',
#  'operator',
#  'secret',
#  'project',
#  'eh',
#  'hand',
#  'everyone',
#  'wit',
#  'ltd',
#  'joy',
#  'father',
#  'darren',
#  'each',
#  'hold',
#  'yar',
#  'saturday',
#  'lucky',
#  'die',
#  'ac',
#  'ten',
#  'talking',
#  'mu',
#  'case',
#  'balance',
#  'currently',
#  'bslvyl',
#  'un',
#  'redeemed',
#  'xy',
#  'congrats',
#  'felt',
#  'askd',
#  'invited',
#  'comes',
#  'questions',
#  'happened',
#  'download',
#  'needs',
#  'eg',
#  'support',
#  'outside',
#  'û_',
#  'mayb',
#  'computer',
#  'sunday',
#  'rental',
#  'land',
#  'ipod',
#  'ugh',
#  'listen',
#  'difficult',
#  'mr',
#  'rply',
#  'march',
#  'red',
#  'offers',
#  'least',
#  'comin',
#  'meant',
#  'remove',
#  'wonderful',
#  'ni',
#  'park',
#  'mrng',
#  'luck',
#  'fucking',
#  'sea',
#  'christmas',
#  'rock',
#  'blue',
#  'valued',
#  'lost',
#  'tickets',
#  'telling',
#  'picking',
#  'extra',
#  'months',
#  'rd',
#  'link',
#  'almost',
#  'supposed',
#  'monday',
#  'hee',
#  'knew',
#  'couple',
#  'caller',
#  'jay',
#  'gone',
#  'kids',
#  'surprise',
#  'swing',
#  'knows',
#  'met',
#  'gn',
#  'wonder',
#  'grins',
#  'wrong',
#  'mah',
#  'within',
#  'rakhesh',
#  'std',
#  'friday',
#  'slowly',
#  'mate',
#  'pic',
#  'gotta',
#  'sex',
#  'point',
#  'kate',
#  'area',
#  'confirm',
#  'uncle',
#  'laptop',
#  'song',
#  'frnds',
#  'press',
#  'reward',
#  'dream',
#  'bath',
#  'wap',
#  'reveal',
#  'gets',
#  'muz',
#  'post',
#  'wasn',
#  'etc',
#  'ldn',
#  'wow',
#  'asking',
#  'india',
#  'bank',
#  'reason',
#  'na',
#  'whole',
#  'john',
#  'mobiles',
#  'energy',
#  'gave',
#  'terms',
#  'dnt',
#  'usf',
#  'crave',
#  'la',
#  'somewhere',
#  'checking',
#  'ass',
#  'enter',
#  'earlier',
#  'less',
#  'congratulations',
#  'via',
#  'il',
#  'wine',
#  'hg',
#  'near',
#  'pass',
#  'street',
#  'glad',
#  'colleagues',
#  'bb',
#  'goodmorning',
#  'freemsg',
#  'moral',
#  'ge',
#  'small',
#  'whenever',
#  'ans',
#  'isn',
#  'feels',
#  'cup',
#  'ex',
#  'somebody',
#  'log',
#  'water',
#  'custcare',
#  'normal',
#  'comp',
#  'save',
#  'dogging',
#  'store',
#  'complimentary',
#  'mm',
#  'write',
#  'lover',
#  'discount',
#  'tc',
#  'tonite',
#  'gettin',
#  'fancy',
#  'ends',
#  'al',
#  'exam',
#  'forwarded',
#  'tht',
#  'direct',
#  'numbers',
#  'correct',
#  'others',
#  'leaves',
#  'tired',
#  'asap',
#  'plans',
#  'ho',
#  'woke',
#  'valentine',
#  'through',
#  'paper',
#  'sell',
#  'orchard',
#  'charity',
#  'fr',
#  'loved',
#  'getzed',
#  'rest',
#  'sick',
#  'lovable',
#  'deep',
#  'frens',
#  'warm',
#  'coffee',
#  'laugh',
#  'bluetooth',
#  'sony',
#  'own',
#  'oops',
#  'shower',
#  'hospital',
#  'nobody',
#  'style',
#  'yahoo',
#  'sub',
#  'polys',
#  'registered',
#  'wana',
#  'figure',
#  'different',
#  'mistake',
#  'alex',
#  'sale',
#  'cheap',
#  'understand',
#  'complete',
#  'stupid',
#  'against',
#  'cut',
#  'representative',
#  'entered',
#  'sofa',
#  'drugs',
#  'sp',
#  'catch',
#  'hmv',
#  'tuesday',
#  'cover',
#  'library',
#  'heard',
#  'happiness',
#  'course',
#  'sign',
#  'charged',
#  'mrt',
#  'england',
#  'reached',
#  'bathe',
#  'sort',
#  'study',
#  ...]

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index2word])
                     for ls in X_test])
# Out:
# C:\Users\34677\anaconda3\lib\site-packages\ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Why is the length of the sentence different than the length of the sentence vector?
for i, v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 34 32
# 16 15
# 22 22
# 7 6
# 11 8
# 3 3
# 19 18
# 13 12
# 19 17
# 9 9
# 12 12
# 22 20
# 19 19
# 27 22
# 7 7
# 4 4
# 5 5
# 26 23
# 4 4
# 14 12
# 23 22
# 30 28
# 15 14
# 19 16
# 16 16
# 34 32
# 16 14
# 4 2
# 16 15
# 4 4
# 5 5
# 21 21
# 5 5
# 10 10
# 6 6
# 6 6
# 23 23
# 5 5
# 18 17
# 26 26
# 25 22
# 27 25
# 30 29
# 27 24
# 3 3
# 4 3
# 11 10
# 11 11
# 17 16
# 7 7
# 18 17
# 30 28
# 15 12
# 14 14
# 12 12
# 28 28
# 10 10
# 5 5
# 25 25
# 20 19
# 49 40
# 47 32
# 4 4
# 29 29
# 6 5
# 18 16
# 22 22
# 7 5
# 13 11
# 9 8
# 6 6
# 21 20
# 9 9
# 6 4
# 6 6
# 6 4
# 10 10
# 8 8
# 11 8
# 27 25
# 6 6
# 6 6
# 22 22
# 24 23
# 19 12
# 12 12
# 5 5
# 0 0
# 22 22
# 6 6
# 17 16
# 6 5
# 5 5
# 22 22
# 13 12
# 5 5
# 8 7
# 13 12
# 12 11
# 23 22
# 15 13
# 17 15
# 10 10
# 8 7
# 16 12
# 4 4
# 14 13
# 8 7
# 6 5
# 30 30
# 23 21
# 13 10
# 9 8
# 23 18
# 21 21
# 14 14
# 2 2
# 6 6
# 17 13
# 12 10
# 50 43
# 6 5
# 7 6
# 19 18
# 11 8
# 20 20
# 30 28
# 3 3
# 16 15
# 20 20
# 11 10
# 9 9
# 6 6
# 6 3
# 9 8
# 7 5
# 6 5
# 16 16
# 29 29
# 5 5
# 23 13
# 5 5
# 26 26
# 4 3
# 7 6
# 27 23
# 5 5
# 24 24
# 6 6
# 16 14
# 8 8
# 12 11
# 3 3
# 10 7
# 5 5
# 31 29
# 16 14
# 8 8
# 9 9
# 9 9
# 14 13
# 6 6
# 1 1
# 8 8
# 21 19
# 52 52
# 23 23
# 10 10
# 11 11
# 17 16
# 25 19
# 16 13
# 17 16
# 6 6
# 25 25
# 9 9
# 6 6
# 6 6
# 7 7
# 6 6
# 5 4
# 25 25
# 7 7
# 9 9
# 56 55
# 26 22
# 24 24
# 14 13
# 9 9
# 25 23
# 8 8
# 21 21
# 5 5
# 12 12
# 5 3
# 6 4
# 1 1
# 20 20
# 13 13
# 21 18
# 24 22
# 49 37
# 4 4
# 9 6
# 5 5
# 9 7
# 11 11
# 23 21
# 7 6
# 6 6
# 7 7
# 15 11
# 14 11
# 19 19
# 20 20
# 12 8
# 6 6
# 6 6
# 20 14
# 25 25
# 12 11
# 17 12
# 20 19
# 8 7
# 24 23
# 28 26
# 27 26
# 21 21
# 8 5
# 3 3
# 10 9
# 23 21
# 13 13
# 9 9
# 7 5
# 4 4
# 7 7
# 4 1
# 10 10
# 8 6
# 17 17
# 24 22
# 33 33
# 9 9
# 9 7
# 21 20
# 5 5
# 30 29
# 6 6
# 10 9
# 25 25
# 7 7
# 5 5
# 5 5
# 14 12
# 5 5
# 8 7
# 5 4
# 8 8
# 12 12
# 18 18
# 9 9
# 6 6
# 6 4
# 5 5
# 0 0
# 4 4
# 15 15
# 9 9
# 12 9
# 5 5
# 9 9
# 10 10
# 6 3
# 20 17
# 33 29
# 29 27
# 5 4
# 14 12
# 5 3
# 23 22
# 10 9
# 21 14
# 5 5
# 5 5
# 26 26
# 26 23
# 14 11
# 15 15
# 9 9
# 29 24
# 11 10
# 5 5
# 11 9
# 3 2
# 13 12
# 24 22
# 12 11
# 8 7
# 10 9
# 15 15
# 11 11
# 16 15
# 12 11
# 8 8
# 24 24
# 12 11
# 4 3
# 7 5
# 6 6
# 5 4
# 22 19
# 8 6
# 12 11
# 22 21
# 10 10
# 29 20
# 9 7
# 6 5
# 12 12
# 4 3
# 5 3
# 8 7
# 19 19
# 23 23
# 7 4
# 8 8
# 5 5
# 6 6
# 22 21
# 6 5
# 4 3
# 8 7
# 8 8
# 6 6
# 13 11
# 10 10
# 14 14
# 18 18
# 11 11
# 13 12
# 7 7
# 4 4
# 74 67
# 8 1
# 21 21
# 19 19
# 9 8
# 21 21
# 7 7
# 4 4
# 8 4
# 2 2
# 15 14
# 6 6
# 36 33
# 26 19
# 8 8
# 7 7
# 23 22
# 18 10
# 12 12
# 8 7
# 21 21
# 26 24
# 8 8
# 14 10
# 9 7
# 5 5
# 4 3
# 9 9
# 9 9
# 8 8
# 24 23
# 19 17
# 18 18
# 10 7
# 18 14
# 7 6
# 7 6
# 12 8
# 26 25
# 21 19
# 20 19
# 28 24
# 15 12
# 6 6
# 15 13
# 5 3
# 15 15
# 22 22
# 5 3
# 6 6
# 7 7
# 12 11
# 56 54
# 7 7
# 6 6
# 36 35
# 55 51
# 12 12
# 7 6
# 16 14
# 8 8
# 22 20
# 5 5
# 24 22
# 10 10
# 10 9
# 11 10
# 8 8
# 29 28
# 7 6
# 5 3
# 16 15
# 23 23
# 20 17
# 6 6
# 22 21
# 9 9
# 23 23
# 8 7
# 6 6
# 29 26
# 15 14
# 9 9
# 1 1
# 17 14
# 4 2
# 24 21
# 20 16
# 5 5
# 11 10
# 15 12
# 40 32
# 11 11
# 12 12
# 6 5
# 13 13
# 23 23
# 21 16
# 22 20
# 23 20
# 6 6
# 4 4
# 15 15
# 8 8
# 7 7
# 38 33
# 23 22
# 9 8
# 21 21
# 6 4
# 31 29
# 13 13
# 22 21
# 29 29
# 7 5
# 7 7
# 6 5
# 18 15
# 27 27
# 6 6
# 4 4
# 7 7
# 3 2
# 5 5
# 5 5
# 24 19
# 10 10
# 17 17
# 9 9
# 27 24
# 15 15
# 12 12
# 9 9
# 6 6
# 7 7
# 31 31
# 21 19
# 6 6
# 9 7
# 1 1
# 19 14
# 6 6
# 12 10
# 5 5
# 18 16
# 8 8
# 13 13
# 4 4
# 21 17
# 8 7
# 20 18
# 16 14
# 14 14
# 8 7
# 17 17
# 9 9
# 15 15
# 9 1
# 9 8
# 27 23
# 29 27
# 8 4
# 4 2
# 23 23
# 17 14
# 16 16
# 8 8
# 18 15
# 4 4
# 25 23
# 14 14
# 24 21
# 17 16
# 17 17
# 9 8
# 28 26
# 5 4
# 6 4
# 11 10
# 5 4
# 17 13
# 23 19
# 12 12
# 8 7
# 27 24
# 12 12
# 5 5
# 11 10
# 11 11
# 5 5
# 7 7
# 9 9
# 6 5
# 11 11
# 7 7
# 24 21
# 14 11
# 7 7
# 19 18
# 7 5
# 26 19
# 1 1
# 10 10
# 11 10
# 14 12
# 11 9
# 23 22
# 9 7
# 6 6
# 10 8
# 14 13
# 25 21
# 9 9
# 27 23
# 21 20
# 4 2
# 25 25
# 8 7
# 21 20
# 8 8
# 8 7
# 9 8
# 5 3
# 26 26
# 9 9
# 17 16
# 12 12
# 28 25
# 6 6
# 41 14
# 9 8
# 16 16
# 4 3
# 32 28
# 10 9
# 3 2
# 5 5
# 9 9
# 5 5
# 25 25
# 27 23
# 8 3
# 9 9
# 5 5
# 5 4
# 21 21
# 36 32
# 12 9
# 9 9
# 8 8
# 16 13
# 28 25
# 15 15
# 5 4
# 12 12
# 25 23
# 5 5
# 11 9
# 7 6
# 6 6
# 24 22
# 22 21
# 6 6
# 27 26
# 5 5
# 7 7
# 7 7
# 28 28
# 14 14
# 22 22
# 20 20
# 33 25
# 29 26
# 35 33
# 8 7
# 7 4
# 19 19
# 8 8
# 4 4
# 24 20
# 9 8
# 8 8
# 5 5
# 29 28
# 3 2
# 12 12
# 28 23
# 23 23
# 6 6
# 9 9
# 7 7
# 12 12
# 12 12
# 25 17
# 7 7
# 14 14
# 33 31
# 8 8
# 5 4
# 23 19
# 26 26
# 6 6
# 33 28
# 4 4
# 29 26
# 54 39
# 10 10
# 29 27
# 5 4
# 16 10
# 10 8
# 3 3
# 8 8
# 9 9
# 5 3
# 8 7
# 5 5
# 20 17
# 11 11
# 1 1
# 24 22
# 4 4
# 18 18
# 8 5
# 11 11
# 6 5
# 21 20
# 6 5
# 13 13
# 26 23
# 7 4
# 8 8
# 37 34
# 15 15
# 8 7
# 12 11
# 9 9
# 27 25
# 7 7
# 13 11
# 27 27
# 25 24
# 20 20
# 5 5
# 17 17
# 5 4
# 24 22
# 4 4
# 22 21
# 8 7
# 9 9
# 26 22
# 9 9
# 7 5
# 30 28
# 12 11
# 21 19
# 7 6
# 21 20
# 12 10
# 18 18
# 7 7
# 22 22
# 12 11
# 6 5
# 27 27
# 24 21
# 30 29
# 5 5
# 21 20
# 11 11
# 22 21
# 25 20
# 27 23
# 26 25
# 33 30
# 3 3
# 11 9
# 35 34
# 10 10
# 6 6
# 8 7
# 23 23
# 7 2
# 12 12
# 9 8
# 1 1
# 6 6
# 2 2
# 13 12
# 8 6
# 8 8
# 7 5
# 5 4
# 12 10
# 27 21
# 8 5
# 7 7
# 14 10
# 9 9
# 5 4
# 7 7
# 13 12
# 27 22
# 31 29
# 18 15
# 4 4
# 24 20
# 11 11
# 20 12
# 11 9
# 5 4
# 8 7
# 7 6
# 8 7
# 22 13
# 7 6
# 5 5
# 22 20
# 5 5
# 4 4
# 8 8
# 81 79
# 17 12
# 18 18
# 1 1
# 7 6
# 13 12
# 8 7
# 8 5
# 20 17
# 13 13
# 6 5
# 5 4
# 7 7
# 29 28
# 27 24
# 20 18
# 26 16
# 21 20
# 8 7
# 24 18
# 16 15
# 17 17
# 24 22
# 28 27
# 18 18
# 7 6
# 30 30
# 15 14
# 18 16
# 4 4
# 20 20
# 28 28
# 25 25
# 7 7
# 10 10
# 3 1
# 12 12
# 23 23
# 28 26
# 11 11
# 5 5
# 19 17
# 6 6
# 10 9
# 20 18
# 7 7
# 4 4
# 4 3
# 8 8
# 19 19
# 5 5
# 5 4
# 16 16
# 6 4
# 15 13
# 9 9
# 11 11
# 9 9
# 6 6
# 9 8
# 5 4
# 18 18
# 14 13
# 8 6
# 26 24
# 18 18
# 28 24
# 23 22
# 8 7
# 60 60
# 13 12
# 1 1
# 13 11
# 7 6
# 16 15
# 1 1
# 0 0
# 6 6
# 4 4
# 25 22
# 6 6
# 6 5
# 17 16
# 11 9
# 11 10
# 12 11
# 5 5
# 8 8
# 24 18
# 12 10
# 17 17
# 11 10
# 19 12
# 8 7
# 5 5
# 1 1
# 23 18
# 27 22
# 21 20
# 10 10
# 23 23
# 23 22
# 18 15
# 6 6
# 21 21
# 16 15
# 27 23
# 19 17
# 12 12
# 7 7
# 12 11
# 8 8
# 17 16
# 22 16
# 11 9
# 5 5
# 27 24
# 9 7
# 25 24
# 7 7
# 8 8
# 16 12
# 25 19
# 7 6
# 29 23
# 20 18
# 16 15
# 5 5
# 13 11
# 7 7
# 29 29
# 30 29
# 5 5
# 31 28
# 4 1
# 7 7
# 11 8
# 24 23
# 23 19
# 10 10
# 2 2
# 9 9
# 10 10
# 7 7
# 6 6
# 66 62
# 18 18
# 25 24
# 12 12
# 18 16
# 24 23
# 18 16
# 20 20
# 5 4
# 33 28
# 27 25
# 6 6
# 16 16
# 24 24
# 10 10
# 6 6
# 6 5
# 19 17
# 8 8
# 30 30
# 16 15
# 17 17
# 2 2
# 2 2
# 12 11
# 4 4
# 3 3
# 8 6
# 8 8
# 17 16
# 20 20
# 10 10
# 7 7
# 7 6
# 4 4
# 9 9
# 4 2
# 8 8
# 3 3
# 21 20
# 18 17
# 9 9
# 7 7
# 8 8
# 9 9
# 19 19
# 6 6
# 15 14
# 25 25
# 11 11
# 11 10
# 10 10
# 3 2
# 24 23
# 6 5
# 8 8
# 20 20
# 5 4
# 5 4
# 14 13
# 20 20
# 11 11
# 14 13
# 3 3
# 5 3
# 13 7
# 6 6
# 6 6
# 13 12
# 4 4
# 8 8
# 13 13
# 10 8
# 6 5
# 13 13
# 24 20
# 7 6
# 9 9
# 13 13
# 7 7
# 25 25
# 23 23
# 9 7
# 17 14
# 21 21
# 33 30
# 9 7
# 14 12
# 19 17
# 5 5
# 21 21
# 4 4
# 14 11
# 8 8
# 23 20
# 9 5
# 13 13
# 13 11
# 176 162
# 22 18
# 9 9
# 6 6
# 9 9
# 20 17
# 11 11
# 17 12
# 25 15
# 7 7
# 18 16
# 27 21
# 9 8
# 4 4
# 8 6
# 13 13
# 7 7
# 22 18
# 7 6
# 8 6
# 26 23
# 17 16
# 7 3
# 8 8
# 10 10
# 26 21
# 9 9
# 9 8
# 24 22
# 16 16
# 8 8
# 20 17
# 22 19
# 5 4
# 11 11
# 5 5
# 8 7
# 6 4
# 11 10
# 21 20
# 18 18
# 8 6
# 19 16
# 5 5
# 16 14
# 6 6
# 8 7
# 3 3
# 6 6
# 7 5
# 7 7
# 25 23
# 17 15
# 5 1
# 27 27
# 20 19
# 23 23
# 13 13
# 22 19
# 13 13
# 19 18
# 18 13
# 8 8
# 5 5
# 44 41
# 6 5
# 7 5
# 11 10
# 5 5
# 21 14
# 10 8
# 22 17
# 38 24
# 26 26
# 5 5
# 34 29
# 6 6
# 9 8
# 7 7
# 6 6
# 13 12
# 4 4
# 5 5
# 16 16
# 23 21
# 6 5
# 16 14
# 21 20
# 5 5
# 11 9
# 7 7
# 17 13
# 16 15
# 7 7
# 18 16
# 13 12
# 27 26
# 17 17
# 22 20
# 5 5
# 1 1
# 8 6
# 16 15
# 28 23
# 6 6
# 25 25
# 7 7

# %%
# Computing sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

# %%
# Are sentence vector lengths consistent?
for i, v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 34 100
# 16 100
# 22 100
# 7 100
# 11 100
# 3 100
# 19 100
# 13 100
# 19 100
# 9 100
# 12 100
# 22 100
# 19 100
# 27 100
# 7 100
# 4 100
# 5 100
# 26 100
# 4 100
# 14 100
# 23 100
# 30 100
# 15 100
# 19 100
# 16 100
# 34 100
# 16 100
# 4 100
# 16 100
# 4 100
# 5 100
# 21 100
# 5 100
# 10 100
# 6 100
# 6 100
# 23 100
# 5 100
# 18 100
# 26 100
# 25 100
# 27 100
# 30 100
# 27 100
# 3 100
# 4 100
# 11 100
# 11 100
# 17 100
# 7 100
# 18 100
# 30 100
# 15 100
# 14 100
# 12 100
# 28 100
# 10 100
# 5 100
# 25 100
# 20 100
# 49 100
# 47 100
# 4 100
# 29 100
# 6 100
# 18 100
# 22 100
# 7 100
# 13 100
# 9 100
# 6 100
# 21 100
# 9 100
# 6 100
# 6 100
# 6 100
# 10 100
# 8 100
# 11 100
# 27 100
# 6 100
# 6 100
# 22 100
# 24 100
# 19 100
# 12 100
# 5 100
# 0 100
# 22 100
# 6 100
# 17 100
# 6 100
# 5 100
# 22 100
# 13 100
# 5 100
# 8 100
# 13 100
# 12 100
# 23 100
# 15 100
# 17 100
# 10 100
# 8 100
# 16 100
# 4 100
# 14 100
# 8 100
# 6 100
# 30 100
# 23 100
# 13 100
# 9 100
# 23 100
# 21 100
# 14 100
# 2 100
# 6 100
# 17 100
# 12 100
# 50 100
# 6 100
# 7 100
# 19 100
# 11 100
# 20 100
# 30 100
# 3 100
# 16 100
# 20 100
# 11 100
# 9 100
# 6 100
# 6 100
# 9 100
# 7 100
# 6 100
# 16 100
# 29 100
# 5 100
# 23 100
# 5 100
# 26 100
# 4 100
# 7 100
# 27 100
# 5 100
# 24 100
# 6 100
# 16 100
# 8 100
# 12 100
# 3 100
# 10 100
# 5 100
# 31 100
# 16 100
# 8 100
# 9 100
# 9 100
# 14 100
# 6 100
# 1 100
# 8 100
# 21 100
# 52 100
# 23 100
# 10 100
# 11 100
# 17 100
# 25 100
# 16 100
# 17 100
# 6 100
# 25 100
# 9 100
# 6 100
# 6 100
# 7 100
# 6 100
# 5 100
# 25 100
# 7 100
# 9 100
# 56 100
# 26 100
# 24 100
# 14 100
# 9 100
# 25 100
# 8 100
# 21 100
# 5 100
# 12 100
# 5 100
# 6 100
# 1 100
# 20 100
# 13 100
# 21 100
# 24 100
# 49 100
# 4 100
# 9 100
# 5 100
# 9 100
# 11 100
# 23 100
# 7 100
# 6 100
# 7 100
# 15 100
# 14 100
# 19 100
# 20 100
# 12 100
# 6 100
# 6 100
# 20 100
# 25 100
# 12 100
# 17 100
# 20 100
# 8 100
# 24 100
# 28 100
# 27 100
# 21 100
# 8 100
# 3 100
# 10 100
# 23 100
# 13 100
# 9 100
# 7 100
# 4 100
# 7 100
# 4 100
# 10 100
# 8 100
# 17 100
# 24 100
# 33 100
# 9 100
# 9 100
# 21 100
# 5 100
# 30 100
# 6 100
# 10 100
# 25 100
# 7 100
# 5 100
# 5 100
# 14 100
# 5 100
# 8 100
# 5 100
# 8 100
# 12 100
# 18 100
# 9 100
# 6 100
# 6 100
# 5 100
# 0 100
# 4 100
# 15 100
# 9 100
# 12 100
# 5 100
# 9 100
# 10 100
# 6 100
# 20 100
# 33 100
# 29 100
# 5 100
# 14 100
# 5 100
# 23 100
# 10 100
# 21 100
# 5 100
# 5 100
# 26 100
# 26 100
# 14 100
# 15 100
# 9 100
# 29 100
# 11 100
# 5 100
# 11 100
# 3 100
# 13 100
# 24 100
# 12 100
# 8 100
# 10 100
# 15 100
# 11 100
# 16 100
# 12 100
# 8 100
# 24 100
# 12 100
# 4 100
# 7 100
# 6 100
# 5 100
# 22 100
# 8 100
# 12 100
# 22 100
# 10 100
# 29 100
# 9 100
# 6 100
# 12 100
# 4 100
# 5 100
# 8 100
# 19 100
# 23 100
# 7 100
# 8 100
# 5 100
# 6 100
# 22 100
# 6 100
# 4 100
# 8 100
# 8 100
# 6 100
# 13 100
# 10 100
# 14 100
# 18 100
# 11 100
# 13 100
# 7 100
# 4 100
# 74 100
# 8 100
# 21 100
# 19 100
# 9 100
# 21 100
# 7 100
# 4 100
# 8 100
# 2 100
# 15 100
# 6 100
# 36 100
# 26 100
# 8 100
# 7 100
# 23 100
# 18 100
# 12 100
# 8 100
# 21 100
# 26 100
# 8 100
# 14 100
# 9 100
# 5 100
# 4 100
# 9 100
# 9 100
# 8 100
# 24 100
# 19 100
# 18 100
# 10 100
# 18 100
# 7 100
# 7 100
# 12 100
# 26 100
# 21 100
# 20 100
# 28 100
# 15 100
# 6 100
# 15 100
# 5 100
# 15 100
# 22 100
# 5 100
# 6 100
# 7 100
# 12 100
# 56 100
# 7 100
# 6 100
# 36 100
# 55 100
# 12 100
# 7 100
# 16 100
# 8 100
# 22 100
# 5 100
# 24 100
# 10 100
# 10 100
# 11 100
# 8 100
# 29 100
# 7 100
# 5 100
# 16 100
# 23 100
# 20 100
# 6 100
# 22 100
# 9 100
# 23 100
# 8 100
# 6 100
# 29 100
# 15 100
# 9 100
# 1 100
# 17 100
# 4 100
# 24 100
# 20 100
# 5 100
# 11 100
# 15 100
# 40 100
# 11 100
# 12 100
# 6 100
# 13 100
# 23 100
# 21 100
# 22 100
# 23 100
# 6 100
# 4 100
# 15 100
# 8 100
# 7 100
# 38 100
# 23 100
# 9 100
# 21 100
# 6 100
# 31 100
# 13 100
# 22 100
# 29 100
# 7 100
# 7 100
# 6 100
# 18 100
# 27 100
# 6 100
# 4 100
# 7 100
# 3 100
# 5 100
# 5 100
# 24 100
# 10 100
# 17 100
# 9 100
# 27 100
# 15 100
# 12 100
# 9 100
# 6 100
# 7 100
# 31 100
# 21 100
# 6 100
# 9 100
# 1 100
# 19 100
# 6 100
# 12 100
# 5 100
# 18 100
# 8 100
# 13 100
# 4 100
# 21 100
# 8 100
# 20 100
# 16 100
# 14 100
# 8 100
# 17 100
# 9 100
# 15 100
# 9 100
# 9 100
# 27 100
# 29 100
# 8 100
# 4 100
# 23 100
# 17 100
# 16 100
# 8 100
# 18 100
# 4 100
# 25 100
# 14 100
# 24 100
# 17 100
# 17 100
# 9 100
# 28 100
# 5 100
# 6 100
# 11 100
# 5 100
# 17 100
# 23 100
# 12 100
# 8 100
# 27 100
# 12 100
# 5 100
# 11 100
# 11 100
# 5 100
# 7 100
# 9 100
# 6 100
# 11 100
# 7 100
# 24 100
# 14 100
# 7 100
# 19 100
# 7 100
# 26 100
# 1 100
# 10 100
# 11 100
# 14 100
# 11 100
# 23 100
# 9 100
# 6 100
# 10 100
# 14 100
# 25 100
# 9 100
# 27 100
# 21 100
# 4 100
# 25 100
# 8 100
# 21 100
# 8 100
# 8 100
# 9 100
# 5 100
# 26 100
# 9 100
# 17 100
# 12 100
# 28 100
# 6 100
# 41 100
# 9 100
# 16 100
# 4 100
# 32 100
# 10 100
# 3 100
# 5 100
# 9 100
# 5 100
# 25 100
# 27 100
# 8 100
# 9 100
# 5 100
# 5 100
# 21 100
# 36 100
# 12 100
# 9 100
# 8 100
# 16 100
# 28 100
# 15 100
# 5 100
# 12 100
# 25 100
# 5 100
# 11 100
# 7 100
# 6 100
# 24 100
# 22 100
# 6 100
# 27 100
# 5 100
# 7 100
# 7 100
# 28 100
# 14 100
# 22 100
# 20 100
# 33 100
# 29 100
# 35 100
# 8 100
# 7 100
# 19 100
# 8 100
# 4 100
# 24 100
# 9 100
# 8 100
# 5 100
# 29 100
# 3 100
# 12 100
# 28 100
# 23 100
# 6 100
# 9 100
# 7 100
# 12 100
# 12 100
# 25 100
# 7 100
# 14 100
# 33 100
# 8 100
# 5 100
# 23 100
# 26 100
# 6 100
# 33 100
# 4 100
# 29 100
# 54 100
# 10 100
# 29 100
# 5 100
# 16 100
# 10 100
# 3 100
# 8 100
# 9 100
# 5 100
# 8 100
# 5 100
# 20 100
# 11 100
# 1 100
# 24 100
# 4 100
# 18 100
# 8 100
# 11 100
# 6 100
# 21 100
# 6 100
# 13 100
# 26 100
# 7 100
# 8 100
# 37 100
# 15 100
# 8 100
# 12 100
# 9 100
# 27 100
# 7 100
# 13 100
# 27 100
# 25 100
# 20 100
# 5 100
# 17 100
# 5 100
# 24 100
# 4 100
# 22 100
# 8 100
# 9 100
# 26 100
# 9 100
# 7 100
# 30 100
# 12 100
# 21 100
# 7 100
# 21 100
# 12 100
# 18 100
# 7 100
# 22 100
# 12 100
# 6 100
# 27 100
# 24 100
# 30 100
# 5 100
# 21 100
# 11 100
# 22 100
# 25 100
# 27 100
# 26 100
# 33 100
# 3 100
# 11 100
# 35 100
# 10 100
# 6 100
# 8 100
# 23 100
# 7 100
# 12 100
# 9 100
# 1 100
# 6 100
# 2 100
# 13 100
# 8 100
# 8 100
# 7 100
# 5 100
# 12 100
# 27 100
# 8 100
# 7 100
# 14 100
# 9 100
# 5 100
# 7 100
# 13 100
# 27 100
# 31 100
# 18 100
# 4 100
# 24 100
# 11 100
# 20 100
# 11 100
# 5 100
# 8 100
# 7 100
# 8 100
# 22 100
# 7 100
# 5 100
# 22 100
# 5 100
# 4 100
# 8 100
# 81 100
# 17 100
# 18 100
# 1 100
# 7 100
# 13 100
# 8 100
# 8 100
# 20 100
# 13 100
# 6 100
# 5 100
# 7 100
# 29 100
# 27 100
# 20 100
# 26 100
# 21 100
# 8 100
# 24 100
# 16 100
# 17 100
# 24 100
# 28 100
# 18 100
# 7 100
# 30 100
# 15 100
# 18 100
# 4 100
# 20 100
# 28 100
# 25 100
# 7 100
# 10 100
# 3 100
# 12 100
# 23 100
# 28 100
# 11 100
# 5 100
# 19 100
# 6 100
# 10 100
# 20 100
# 7 100
# 4 100
# 4 100
# 8 100
# 19 100
# 5 100
# 5 100
# 16 100
# 6 100
# 15 100
# 9 100
# 11 100
# 9 100
# 6 100
# 9 100
# 5 100
# 18 100
# 14 100
# 8 100
# 26 100
# 18 100
# 28 100
# 23 100
# 8 100
# 60 100
# 13 100
# 1 100
# 13 100
# 7 100
# 16 100
# 1 100
# 0 100
# 6 100
# 4 100
# 25 100
# 6 100
# 6 100
# 17 100
# 11 100
# 11 100
# 12 100
# 5 100
# 8 100
# 24 100
# 12 100
# 17 100
# 11 100
# 19 100
# 8 100
# 5 100
# 1 100
# 23 100
# 27 100
# 21 100
# 10 100
# 23 100
# 23 100
# 18 100
# 6 100
# 21 100
# 16 100
# 27 100
# 19 100
# 12 100
# 7 100
# 12 100
# 8 100
# 17 100
# 22 100
# 11 100
# 5 100
# 27 100
# 9 100
# 25 100
# 7 100
# 8 100
# 16 100
# 25 100
# 7 100
# 29 100
# 20 100
# 16 100
# 5 100
# 13 100
# 7 100
# 29 100
# 30 100
# 5 100
# 31 100
# 4 100
# 7 100
# 11 100
# 24 100
# 23 100
# 10 100
# 2 100
# 9 100
# 10 100
# 7 100
# 6 100
# 66 100
# 18 100
# 25 100
# 12 100
# 18 100
# 24 100
# 18 100
# 20 100
# 5 100
# 33 100
# 27 100
# 6 100
# 16 100
# 24 100
# 10 100
# 6 100
# 6 100
# 19 100
# 8 100
# 30 100
# 16 100
# 17 100
# 2 100
# 2 100
# 12 100
# 4 100
# 3 100
# 8 100
# 8 100
# 17 100
# 20 100
# 10 100
# 7 100
# 7 100
# 4 100
# 9 100
# 4 100
# 8 100
# 3 100
# 21 100
# 18 100
# 9 100
# 7 100
# 8 100
# 9 100
# 19 100
# 6 100
# 15 100
# 25 100
# 11 100
# 11 100
# 10 100
# 3 100
# 24 100
# 6 100
# 8 100
# 20 100
# 5 100
# 5 100
# 14 100
# 20 100
# 11 100
# 14 100
# 3 100
# 5 100
# 13 100
# 6 100
# 6 100
# 13 100
# 4 100
# 8 100
# 13 100
# 10 100
# 6 100
# 13 100
# 24 100
# 7 100
# 9 100
# 13 100
# 7 100
# 25 100
# 23 100
# 9 100
# 17 100
# 21 100
# 33 100
# 9 100
# 14 100
# 19 100
# 5 100
# 21 100
# 4 100
# 14 100
# 8 100
# 23 100
# 9 100
# 13 100
# 13 100
# 176 100
# 22 100
# 9 100
# 6 100
# 9 100
# 20 100
# 11 100
# 17 100
# 25 100
# 7 100
# 18 100
# 27 100
# 9 100
# 4 100
# 8 100
# 13 100
# 7 100
# 22 100
# 7 100
# 8 100
# 26 100
# 17 100
# 7 100
# 8 100
# 10 100
# 26 100
# 9 100
# 9 100
# 24 100
# 16 100
# 8 100
# 20 100
# 22 100
# 5 100
# 11 100
# 5 100
# 8 100
# 6 100
# 11 100
# 21 100
# 18 100
# 8 100
# 19 100
# 5 100
# 16 100
# 6 100
# 8 100
# 3 100
# 6 100
# 7 100
# 7 100
# 25 100
# 17 100
# 5 100
# 27 100
# 20 100
# 23 100
# 13 100
# 22 100
# 13 100
# 19 100
# 18 100
# 8 100
# 5 100
# 44 100
# 6 100
# 7 100
# 11 100
# 5 100
# 21 100
# 10 100
# 22 100
# 38 100
# 26 100
# 5 100
# 34 100
# 6 100
# 9 100
# 7 100
# 6 100
# 13 100
# 4 100
# 5 100
# 16 100
# 23 100
# 6 100
# 16 100
# 21 100
# 5 100
# 11 100
# 7 100
# 17 100
# 16 100
# 7 100
# 18 100
# 13 100
# 27 100
# 17 100
# 22 100
# 5 100
# 1 100
# 8 100
# 16 100
# 28 100
# 6 100
# 25 100
# 7 100
